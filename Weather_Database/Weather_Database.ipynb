# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
   
   

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | aksu
# Processing Record 3 of Set 1 | san rafael
# Processing Record 4 of Set 1 | vostok
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | urubamba
# Processing Record 10 of Set 1 | tubuala
# Processing Record 11 of Set 1 | pochutla
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | ahipara
# Processing Record 16 of Set 1 | ponta delgada
# Processing Record 17 of Set 1 | sistranda
# Processing Record 18 of Set 1 | atasu
# Processing Record 19 of Set 1 | samarai
# Processing Record 20 of Set 1 | byron bay
# Processing Record 21 of Set 1 | bontang
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | ostrovnoy
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | buala
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | coquimbo
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | vila franca do campo
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | andenes
# Processing Record 36 of Set 1 | chapleau
# Processing Record 37 of Set 1 | fukuchiyama
# Processing Record 38 of Set 1 | iskateley
# Processing Record 39 of Set 1 | pampas
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | korogwe
# City not found. Skipping...
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | lazaro cardenas
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | yeppoon
# Processing Record 47 of Set 1 | qui nhon
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 2 | teknaf
# Processing Record 3 of Set 2 | altay
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | quatre cocos
# Processing Record 7 of Set 2 | ziro
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | pangoa
# Processing Record 11 of Set 2 | mtambile
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | muros
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 16 of Set 2 | ariquemes
# Processing Record 17 of Set 2 | moose factory
# Processing Record 18 of Set 2 | cap malheureux
# Processing Record 19 of Set 2 | mookane
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | zaltan
# Processing Record 22 of Set 2 | panzhihua
# Processing Record 23 of Set 2 | bangkalan
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | aden
# Processing Record 27 of Set 2 | semnan
# Processing Record 28 of Set 2 | loanda
# Processing Record 29 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | totness
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | phan thiet
# Processing Record 34 of Set 2 | waipawa
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | jalu
# Processing Record 40 of Set 2 | alyangula
# Processing Record 41 of Set 2 | goderich
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | salina cruz
# Processing Record 44 of Set 2 | klaksvik
# Processing Record 45 of Set 2 | pringsewu
# Processing Record 46 of Set 2 | farmington
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | nanchong
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | dolores
# Processing Record 4 of Set 3 | saint-augustin
# Processing Record 5 of Set 3 | san cristobal
# Processing Record 6 of Set 3 | benemerito de las americas
# Processing Record 7 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 3 | ushuaia
# Processing Record 9 of Set 3 | birao
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | kemijarvi
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | watari
# Processing Record 16 of Set 3 | bara
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | espumoso
# Processing Record 22 of Set 3 | tual
# Processing Record 23 of Set 3 | lakota
# Processing Record 24 of Set 3 | kapaa
# Processing Record 25 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | kvarkeno
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | okhotsk
# Processing Record 31 of Set 3 | chodavaram
# Processing Record 32 of Set 3 | coihaique
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 3 | rikitea
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | port augusta
# Processing Record 39 of Set 3 | linhares
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | elko
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 3 | mubende
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | moussoro
# Processing Record 3 of Set 4 | dunedin
# Processing Record 4 of Set 4 | alamos
# Processing Record 5 of Set 4 | lodja
# Processing Record 6 of Set 4 | dulce nombre de culmi
# Processing Record 7 of Set 4 | ozinki
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | tikalaan
# City not found. Skipping...
# Processing Record 10 of Set 4 | pervomaysk
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | cranbrook
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | islamkot
# Processing Record 16 of Set 4 | serenje
# Processing Record 17 of Set 4 | kupang
# Processing Record 18 of Set 4 | goure
# Processing Record 19 of Set 4 | kurilsk
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | sao raimundo das mangabeiras
# Processing Record 22 of Set 4 | akureyri
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | koungheul
# Processing Record 26 of Set 4 | nelson bay
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | badou
# Processing Record 29 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 30 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 4 | vila velha
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | weesp
# Processing Record 34 of Set 4 | kafanchan
# Processing Record 35 of Set 4 | vilyuysk
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 4 | kosonsoy
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | hwange
# Processing Record 41 of Set 4 | la asuncion
# Processing Record 42 of Set 4 | kyra
# Processing Record 43 of Set 4 | garowe
# Processing Record 44 of Set 4 | abu samrah
# Processing Record 45 of Set 4 | vanavara
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | maromitsa
# Processing Record 48 of Set 4 | tierranueva
# Processing Record 49 of Set 4 | finschhafen
# Processing Record 50 of Set 4 | port hedland
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | iaciara
# Processing Record 3 of Set 5 | hermanus
# Processing Record 4 of Set 5 | vardo
# Processing Record 5 of Set 5 | rawson
# Processing Record 6 of Set 5 | yerbogachen
# Processing Record 7 of Set 5 | luganville
# Processing Record 8 of Set 5 | sainte-anne-des-monts
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | mumford
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | port lincoln
# Processing Record 13 of Set 5 | xichang
# Processing Record 14 of Set 5 | batitang
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | oum hadjer
# Processing Record 17 of Set 5 | sao filipe
# Processing Record 18 of Set 5 | swan river
# Processing Record 19 of Set 5 | lengyeltoti
# Processing Record 20 of Set 5 | aswan
# Processing Record 21 of Set 5 | sangar
# Processing Record 22 of Set 5 | ambilobe
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | gornyak
# Processing Record 27 of Set 5 | half moon bay
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | la orilla
# Processing Record 30 of Set 5 | arrifes
# Processing Record 31 of Set 5 | ermoupolis
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | boueni
# Processing Record 35 of Set 5 | banjar
# Processing Record 36 of Set 5 | dartford
# Processing Record 37 of Set 5 | tarhunah
# City not found. Skipping...
# Processing Record 38 of Set 5 | lahaina
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | saladoblanco
# Processing Record 42 of Set 5 | sakakah
# Processing Record 43 of Set 5 | kourou
# Processing Record 44 of Set 5 | jumla
# Processing Record 45 of Set 5 | salalah
# Processing Record 46 of Set 5 | spearfish
# Processing Record 47 of Set 5 | ylojarvi
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | harper
# Processing Record 50 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 6 | sharjah
# Processing Record 2 of Set 6 | sesheke
# Processing Record 3 of Set 6 | mokokchung
# Processing Record 4 of Set 6 | honiara
# Processing Record 5 of Set 6 | gogrial
# Processing Record 6 of Set 6 | joensuu
# Processing Record 7 of Set 6 | khatanga
# Processing Record 8 of Set 6 | kumluca
# Processing Record 9 of Set 6 | kuusamo
# Processing Record 10 of Set 6 | lithakia
# Processing Record 11 of Set 6 | hukuntsi
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | nabire
# Processing Record 15 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 16 of Set 6 | salinas
# Processing Record 17 of Set 6 | pangody
# Processing Record 18 of Set 6 | muravlenko
# Processing Record 19 of Set 6 | lodwar
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | panguna
# Processing Record 23 of Set 6 | chicama
# Processing Record 24 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 6 | kampong chhnang
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | pauini
# Processing Record 28 of Set 6 | touros
# Processing Record 29 of Set 6 | beroroha
# Processing Record 30 of Set 6 | sena madureira
# Processing Record 31 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 32 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 6 | viedma
# Processing Record 34 of Set 6 | tuatapere
# Processing Record 35 of Set 6 | acarau
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | deputatskiy
# Processing Record 40 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 41 of Set 6 | nouadhibou
# Processing Record 42 of Set 6 | shache
# Processing Record 43 of Set 6 | uniao da victoria
# City not found. Skipping...
# Processing Record 44 of Set 6 | shingu
# Processing Record 45 of Set 6 | macusani
# Processing Record 46 of Set 6 | etropole
# Processing Record 47 of Set 6 | terrace bay
# Processing Record 48 of Set 6 | codrington
# Processing Record 49 of Set 6 | alofi
# Processing Record 50 of Set 6 | maniitsoq
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | cikupa
# Processing Record 3 of Set 7 | tabuk
# Processing Record 4 of Set 7 | todos santos
# Processing Record 5 of Set 7 | norman wells
# Processing Record 6 of Set 7 | durban
# Processing Record 7 of Set 7 | damavand
# Processing Record 8 of Set 7 | kishi
# Processing Record 9 of Set 7 | makakilo city
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | north bend
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | ambon
# Processing Record 14 of Set 7 | erdenet
# Processing Record 15 of Set 7 | nadym
# Processing Record 16 of Set 7 | sur
# Processing Record 17 of Set 7 | akyab
# Processing Record 18 of Set 7 | merauke
# Processing Record 19 of Set 7 | bhasawar
# Processing Record 20 of Set 7 | alirajpur
# Processing Record 21 of Set 7 | verkhoyansk
# Processing Record 22 of Set 7 | belaya gora
# Processing Record 23 of Set 7 | cabedelo
# Processing Record 24 of Set 7 | ribeira grande
# Processing Record 25 of Set 7 | tondano
# Processing Record 26 of Set 7 | rodrigues alves
# Processing Record 27 of Set 7 | dhidhdhoo
# Processing Record 28 of Set 7 | balkhash
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | kudahuvadhoo
# Processing Record 32 of Set 7 | vila
# Processing Record 33 of Set 7 | taunggyi
# Processing Record 34 of Set 7 | san andres
# Processing Record 35 of Set 7 | naron
# Processing Record 36 of Set 7 | baykit
# Processing Record 37 of Set 7 | eureka
# Processing Record 38 of Set 7 | nizhniy tsasuchey
# Processing Record 39 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 7 | esperance
# Processing Record 41 of Set 7 | pacific grove
# Processing Record 42 of Set 7 | mahon
# Processing Record 43 of Set 7 | ilulissat
# Processing Record 44 of Set 7 | virginia beach
# Processing Record 45 of Set 7 | krabi
# Processing Record 46 of Set 7 | mundra
# Processing Record 47 of Set 7 | anzio
# Processing Record 48 of Set 7 | nova olimpia
# Processing Record 49 of Set 7 | waddan
# Processing Record 50 of Set 7 | tutoia
# Processing Record 1 of Set 8 | berbera
# Processing Record 2 of Set 8 | quelimane
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | mujiayingzi
# Processing Record 5 of Set 8 | mastic beach
# Processing Record 6 of Set 8 | nelson
# Processing Record 7 of Set 8 | sorland
# Processing Record 8 of Set 8 | gorontalo
# Processing Record 9 of Set 8 | manaure
# Processing Record 10 of Set 8 | airai
# Processing Record 11 of Set 8 | olinda
# Processing Record 12 of Set 8 | bhag
# Processing Record 13 of Set 8 | lata
# Processing Record 14 of Set 8 | astoria
# Processing Record 15 of Set 8 | sao jeronimo
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | christchurch
# Processing Record 18 of Set 8 | jeremie
# Processing Record 19 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 8 | khairpur nathan shah
# Processing Record 21 of Set 8 | nautla
# Processing Record 22 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 8 | margate
# Processing Record 24 of Set 8 | marijampole
# Processing Record 25 of Set 8 | arraial do cabo
# Processing Record 26 of Set 8 | corner brook
# Processing Record 27 of Set 8 | portland
# Processing Record 28 of Set 8 | mehamn
# Processing Record 29 of Set 8 | hamilton
# Processing Record 30 of Set 8 | traverse city
# Processing Record 31 of Set 8 | batagay
# Processing Record 32 of Set 8 | taksimo
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | wairoa
# Processing Record 35 of Set 8 | isiro
# Processing Record 36 of Set 8 | romny
# Processing Record 37 of Set 8 | karratha
# Processing Record 38 of Set 8 | tyup
# Processing Record 39 of Set 8 | vernon
# Processing Record 40 of Set 8 | emba
# Processing Record 41 of Set 8 | hervey bay
# Processing Record 42 of Set 8 | emerald
# Processing Record 43 of Set 8 | buzmeyin
# Processing Record 44 of Set 8 | la mana
# Processing Record 45 of Set 8 | noumea
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | marsa matruh
# Processing Record 48 of Set 8 | camacha
# Processing Record 49 of Set 8 | escanaba
# Processing Record 50 of Set 8 | isla vista
# Processing Record 1 of Set 9 | egvekinot
# Processing Record 2 of Set 9 | alibag
# Processing Record 3 of Set 9 | wangqing
# Processing Record 4 of Set 9 | pakxe
# Processing Record 5 of Set 9 | rocha
# Processing Record 6 of Set 9 | kita
# Processing Record 7 of Set 9 | high prairie
# Processing Record 8 of Set 9 | nouakchott
# Processing Record 9 of Set 9 | port macquarie
# Processing Record 10 of Set 9 | osakarovka
# Processing Record 11 of Set 9 | liwale
# Processing Record 12 of Set 9 | rio grande
# Processing Record 13 of Set 9 | arica
# Processing Record 14 of Set 9 | tahoua
# Processing Record 15 of Set 9 | slave lake
# Processing Record 16 of Set 9 | chinhoyi
# Processing Record 17 of Set 9 | north myrtle beach
# Processing Record 18 of Set 9 | sirjan
# Processing Record 19 of Set 9 | yako
# Processing Record 20 of Set 9 | udachnyy
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | cayenne
# Processing Record 23 of Set 9 | floro
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | bilibino
# Processing Record 26 of Set 9 | narsaq
# Processing Record 27 of Set 9 | bani walid
# Processing Record 28 of Set 9 | chara
# Processing Record 29 of Set 9 | kerchevskiy
# Processing Record 30 of Set 9 | srikakulam
# Processing Record 31 of Set 9 | bambanglipuro
# Processing Record 32 of Set 9 | bijar
# Processing Record 33 of Set 9 | letohrad
# Processing Record 34 of Set 9 | chilca
# Processing Record 35 of Set 9 | januaria
# Processing Record 36 of Set 9 | bone
# Processing Record 37 of Set 9 | aitape
# Processing Record 38 of Set 9 | ust-tsilma
# Processing Record 39 of Set 9 | remanso
# Processing Record 40 of Set 9 | gouyave
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | anadyr
# Processing Record 43 of Set 9 | vladimir
# Processing Record 44 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 9 | sola
# Processing Record 46 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 47 of Set 9 | luxeuil-les-bains
# Processing Record 48 of Set 9 | hillsborough
# Processing Record 49 of Set 9 | takoradi
# Processing Record 50 of Set 9 | pozoblanco
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | mount isa
# Processing Record 3 of Set 10 | minab
# Processing Record 4 of Set 10 | axim
# Processing Record 5 of Set 10 | hermiston
# Processing Record 6 of Set 10 | karatuzskoye
# Processing Record 7 of Set 10 | hay river
# Processing Record 8 of Set 10 | chichigalpa
# Processing Record 9 of Set 10 | saint-pierre
# Processing Record 10 of Set 10 | opotiki
# Processing Record 11 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 10 | acapulco
# Processing Record 13 of Set 10 | lerwick
# Processing Record 14 of Set 10 | lakatoro
# Processing Record 15 of Set 10 | avera
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | suifenhe
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | northam
# Processing Record 20 of Set 10 | kinkala
# Processing Record 21 of Set 10 | rio claro
# Processing Record 22 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 10 | menongue
# Processing Record 24 of Set 10 | szentistvan
# Processing Record 25 of Set 10 | college
# Processing Record 26 of Set 10 | banda aceh
# Processing Record 27 of Set 10 | bismarck
# Processing Record 28 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 10 | krasnoselkup
# Processing Record 30 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | ambanja
# Processing Record 32 of Set 10 | yanam
# Processing Record 33 of Set 10 | talnakh
# Processing Record 34 of Set 10 | mocuba
# Processing Record 35 of Set 10 | westport
# Processing Record 36 of Set 10 | hutchinson
# Processing Record 37 of Set 10 | srandakan
# Processing Record 38 of Set 10 | kargasok
# Processing Record 39 of Set 10 | sao paulo de olivenca
# Processing Record 40 of Set 10 | inhambane
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | bristol
# Processing Record 43 of Set 10 | susanville
# Processing Record 44 of Set 10 | sohbatpur
# Processing Record 45 of Set 10 | juneau
# Processing Record 46 of Set 10 | plettenberg bay
# Processing Record 47 of Set 10 | dir
# Processing Record 48 of Set 10 | sabancuy
# Processing Record 49 of Set 10 | daru
# Processing Record 50 of Set 10 | huarmey
# Processing Record 1 of Set 11 | el vigia
# Processing Record 2 of Set 11 | el negrito
# Processing Record 3 of Set 11 | souillac
# Processing Record 4 of Set 11 | union hidalgo
# Processing Record 5 of Set 11 | baduria
# Processing Record 6 of Set 11 | bull savanna
# Processing Record 7 of Set 11 | monrovia
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | natal
# Processing Record 10 of Set 11 | teguise
# Processing Record 11 of Set 11 | aykhal
# Processing Record 12 of Set 11 | afantou
# Processing Record 13 of Set 11 | takaka
# Processing Record 14 of Set 11 | bintulu
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | antalaha
# Processing Record 17 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 11 | bandarbeyla
# Processing Record 19 of Set 11 | kangundo
# Processing Record 20 of Set 11 | sungaipenuh
# Processing Record 21 of Set 11 | isangel
# Processing Record 22 of Set 11 | dubti
# Processing Record 23 of Set 11 | sulangan
# Processing Record 24 of Set 11 | kurumkan
# Processing Record 25 of Set 11 | fort morgan
# Processing Record 26 of Set 11 | labuhan
# Processing Record 27 of Set 11 | suoyarvi
# Processing Record 28 of Set 11 | malkara
# Processing Record 29 of Set 11 | manokwari
# Processing Record 30 of Set 11 | paka
# Processing Record 31 of Set 11 | warrington
# Processing Record 32 of Set 11 | kapoeta
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | vytegra
# Processing Record 35 of Set 11 | chopda
# Processing Record 36 of Set 11 | maputo
# Processing Record 37 of Set 11 | panixtlahuaca
# City not found. Skipping...
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | camabatela
# Processing Record 40 of Set 11 | hurghada
# Processing Record 41 of Set 11 | canico
# Processing Record 42 of Set 11 | dzhebariki-khaya
# Processing Record 43 of Set 11 | pokhara
# Processing Record 44 of Set 11 | russell
# Processing Record 45 of Set 11 | ubaitaba
# Processing Record 46 of Set 11 | saint-joseph
# Processing Record 47 of Set 11 | saurimo
# Processing Record 48 of Set 11 | gurupi
# Processing Record 49 of Set 11 | orlik
# Processing Record 50 of Set 11 | pangnirtung
# Processing Record 1 of Set 12 | isagarh
# Processing Record 2 of Set 12 | ballina
# Processing Record 3 of Set 12 | los negros
# Processing Record 4 of Set 12 | urengoy
# Processing Record 5 of Set 12 | saraland
# Processing Record 6 of Set 12 | chkalovsk
# Processing Record 7 of Set 12 | kribi
# Processing Record 8 of Set 12 | phangnga
# Processing Record 9 of Set 12 | vuktyl
# Processing Record 10 of Set 12 | ambulu
# Processing Record 11 of Set 12 | cascais
# Processing Record 12 of Set 12 | wolmirstedt
# Processing Record 13 of Set 12 | yarada
# Processing Record 14 of Set 12 | poshekhonye
# Processing Record 15 of Set 12 | lavrentiya
# Processing Record 16 of Set 12 | ozernovskiy
# Processing Record 17 of Set 12 | huadian
# Processing Record 18 of Set 12 | kawalu
# Processing Record 19 of Set 12 | majene
# Processing Record 20 of Set 12 | chancay
# Processing Record 21 of Set 12 | kamenka
# Processing Record 22 of Set 12 | nemuro
# Processing Record 23 of Set 12 | dalnegorsk
# Processing Record 24 of Set 12 | north platte
# Processing Record 25 of Set 12 | fare
# Processing Record 26 of Set 12 | saldanha
# Processing Record 27 of Set 12 | haimen
# Processing Record 28 of Set 12 | tucumcari
# Processing Record 29 of Set 12 | tessalit
# Processing Record 30 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 12 | chahal
# Processing Record 32 of Set 12 | havelock
# Processing Record 33 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 34 of Set 12 | sisimiut
# Processing Record 35 of Set 12 | mendi
# Processing Record 36 of Set 12 | visegrad
# Processing Record 37 of Set 12 | san luis
# Processing Record 38 of Set 12 | gamba
# Processing Record 39 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 12 | paita
# Processing Record 41 of Set 12 | koprivnica
# Processing Record 42 of Set 12 | yar-sale
# Processing Record 43 of Set 12 | gra liyia
# Processing Record 44 of Set 12 | skjervoy
# Processing Record 45 of Set 12 | manoharpur
# Processing Record 46 of Set 12 | laguna
# Processing Record 47 of Set 12 | shubarkuduk
# Processing Record 48 of Set 12 | vung tau
# Processing Record 49 of Set 12 | smithers
# Processing Record 50 of Set 12 | hambantota
# Processing Record 1 of Set 13 | netivot
# Processing Record 2 of Set 13 | miri
# Processing Record 3 of Set 13 | zhoucun
# Processing Record 4 of Set 13 | thinadhoo
# Processing Record 5 of Set 13 | rochegda
# Processing Record 6 of Set 13 | dorado
# Processing Record 7 of Set 13 | boat of garten
# Processing Record 8 of Set 13 | general pico
# Processing Record 9 of Set 13 | namatanai
# Processing Record 10 of Set 13 | koslan
# Processing Record 11 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 13 | qax
# Processing Record 13 of Set 13 | usinsk
# Processing Record 14 of Set 13 | bor
# Processing Record 15 of Set 13 | suntar
# Processing Record 16 of Set 13 | karlskoga
# Processing Record 17 of Set 13 | tshane
# Processing Record 18 of Set 13 | jundubah
# City not found. Skipping...
# Processing Record 19 of Set 13 | salinopolis
# Processing Record 20 of Set 13 | naze
# Processing Record 21 of Set 13 | belmonte
# Processing Record 22 of Set 13 | port-gentil
# Processing Record 23 of Set 13 | obo
# Processing Record 24 of Set 13 | calbuco
# Processing Record 25 of Set 13 | dzilam gonzalez
# Processing Record 26 of Set 13 | nioro
# Processing Record 27 of Set 13 | talaya
# Processing Record 28 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 13 | clyde river
# Processing Record 30 of Set 13 | hue
# Processing Record 31 of Set 13 | ileza
# Processing Record 32 of Set 13 | port moresby
# Processing Record 33 of Set 13 | borogontsy
# Processing Record 34 of Set 13 | saint-paul-les-dax
# Processing Record 35 of Set 13 | beringovskiy
# Processing Record 36 of Set 13 | dali
# Processing Record 37 of Set 13 | fossombrone
# Processing Record 38 of Set 13 | zhigansk
# Processing Record 39 of Set 13 | voi
# Processing Record 40 of Set 13 | presidencia roque saenz pena
# Processing Record 41 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 42 of Set 13 | mnogovershinnyy
# Processing Record 43 of Set 13 | kloulklubed
# Processing Record 44 of Set 13 | manoel urbano
# Processing Record 45 of Set 13 | santa cruz
# Processing Record 46 of Set 13 | ibotirama
# Processing Record 47 of Set 13 | clearlake
# Processing Record 48 of Set 13 | keita
# Processing Record 49 of Set 13 | chlorakas
# Processing Record 50 of Set 13 | tucuma
# Processing Record 1 of Set 14 | ndele
# Processing Record 2 of Set 14 | miraflores
# Processing Record 3 of Set 14 | otane
# Processing Record 4 of Set 14 | provost
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | pinawa
# Processing Record 7 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 14 | antofagasta
# Processing Record 9 of Set 14 | roma
# Processing Record 10 of Set 14 | linjiang
# Processing Record 11 of Set 14 | pandamatenga
# Processing Record 12 of Set 14 | umm lajj
# Processing Record 13 of Set 14 | pyay
# Processing Record 14 of Set 14 | romitan
# Processing Record 15 of Set 14 | port hardy
# Processing Record 16 of Set 14 | roald
# Processing Record 17 of Set 14 | gejiu
# Processing Record 18 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 14 | tazovskiy
# Processing Record 20 of Set 14 | vredendal
# Processing Record 21 of Set 14 | yarmouth
# Processing Record 22 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 23 of Set 14 | buraydah
# Processing Record 24 of Set 14 | senno
# Processing Record 25 of Set 14 | inuvik
# Processing Record 26 of Set 14 | rolla
# Processing Record 27 of Set 14 | dicabisagan
# Processing Record 28 of Set 14 | la ronge
# Processing Record 29 of Set 14 | loandjili
# Processing Record 30 of Set 14 | palmas bellas
# Processing Record 31 of Set 14 | svetlogorsk
# Processing Record 32 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 14 | labuan
# Processing Record 34 of Set 14 | bar harbor
# Processing Record 35 of Set 14 | gizo
# Processing Record 36 of Set 14 | fukue
# Processing Record 37 of Set 14 | goksun
# Processing Record 38 of Set 14 | bontoc
# Processing Record 39 of Set 14 | pankrushikha
# Processing Record 40 of Set 14 | bejar
# Processing Record 41 of Set 14 | ivolginsk
# Processing Record 42 of Set 14 | say
# Processing Record 43 of Set 14 | flin flon
# Processing Record 44 of Set 14 | taiyuan
# Processing Record 45 of Set 14 | findlay
# Processing Record 46 of Set 14 | caborca
# Processing Record 47 of Set 14 | hyeres
# Processing Record 48 of Set 14 | halifax
# Processing Record 49 of Set 14 | nara
# Processing Record 50 of Set 14 | malindi
# Processing Record 1 of Set 15 | qazvin
# Processing Record 2 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 3 of Set 15 | la ciotat
# Processing Record 4 of Set 15 | pundaguitan
# Processing Record 5 of Set 15 | ubatuba
# Processing Record 6 of Set 15 | zhangye
# Processing Record 7 of Set 15 | guimar
# Processing Record 8 of Set 15 | akhisar
# Processing Record 9 of Set 15 | carnot
# Processing Record 10 of Set 15 | port blair
# Processing Record 11 of Set 15 | sabha
# Processing Record 12 of Set 15 | mayo
# Processing Record 13 of Set 15 | buluang
# Processing Record 14 of Set 15 | sawtell
# Processing Record 15 of Set 15 | siocon
# Processing Record 16 of Set 15 | rio gallegos
# Processing Record 17 of Set 15 | khonsar
# City not found. Skipping...
# Processing Record 18 of Set 15 | constitucion
# Processing Record 19 of Set 15 | lasa
# Processing Record 20 of Set 15 | crestview
# Processing Record 21 of Set 15 | gasa
# Processing Record 22 of Set 15 | siguiri
# Processing Record 23 of Set 15 | barra
# Processing Record 24 of Set 15 | kenora
# Processing Record 25 of Set 15 | yola
# Processing Record 26 of Set 15 | gao
# Processing Record 27 of Set 15 | baraki barak
# Processing Record 28 of Set 15 | magistralnyy
# Processing Record 29 of Set 15 | talcahuano
# Processing Record 30 of Set 15 | sheridan
# Processing Record 31 of Set 15 | korla
# Processing Record 32 of Set 15 | okahandja
# Processing Record 33 of Set 15 | sarkand
# Processing Record 34 of Set 15 | redmond
# Processing Record 35 of Set 15 | chaozhou
# Processing Record 36 of Set 15 | harnosand
# Processing Record 37 of Set 15 | san carlos de bariloche
# Processing Record 38 of Set 15 | sarwar
# Processing Record 39 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 15 | arcachon
# Processing Record 41 of Set 15 | ugoofaaru
# Processing Record 42 of Set 15 | nikel
# Processing Record 43 of Set 15 | kars
# Processing Record 44 of Set 15 | oldmeldrum
# Processing Record 45 of Set 15 | stephenville crossing
# Processing Record 46 of Set 15 | tromso
# Processing Record 47 of Set 15 | hualmay
# Processing Record 48 of Set 15 | quang ngai
# Processing Record 49 of Set 15 | klodzko
# Processing Record 50 of Set 15 | tiznit
# Processing Record 1 of Set 16 | sibolga
# Processing Record 2 of Set 16 | bereznehuvate
# Processing Record 3 of Set 16 | havoysund
# Processing Record 4 of Set 16 | glenwood springs
# Processing Record 5 of Set 16 | puerto escondido
# Processing Record 6 of Set 16 | brindisi
# Processing Record 7 of Set 16 | saint-georges
# Processing Record 8 of Set 16 | mariental
# Processing Record 9 of Set 16 | oriximina
# Processing Record 10 of Set 16 | high level
# Processing Record 11 of Set 16 | meulaboh
# Processing Record 12 of Set 16 | khipro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari   3.0707  172.7902     82.49        74          46
# 1          Aksu  41.1231   80.2644     89.89        19           0
# 2    San Rafael -34.6177  -68.3301     42.35        47          28
# 3        Vostok  46.4856  135.8833     85.32        58         100
# 4     Busselton -33.6500  115.3333     52.09        57         100
# 5  Ponta Do Sol  32.6667  -17.1000     72.72        71           2
# 6        Albany  42.6001  -73.9662     72.25        79           0
# 7      Urubamba -13.3047  -72.1158     52.70        87           8
# 8       Tubuala   9.5167  -79.0333     78.33        86         100
# 9      Pochutla  15.7432  -96.4661     82.81        92         100
#
#    Wind Speed Country Current Description
# 0        7.09      KI          light rain
# 1        6.11      CN           clear sky
# 2        3.60      AR    scattered clouds
# 3        4.18      RU     overcast clouds
# 4       26.02      AU     overcast clouds
# 5        5.55      PT           clear sky
# 6        1.01      US           clear sky
# 7        5.19      PE           clear sky
# 8        6.08      PA     overcast clouds
# 9        2.82      MX     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.0707  172.7902     82.49        74          46
# 1          Aksu      CN  41.1231   80.2644     89.89        19           0
# 2    San Rafael      AR -34.6177  -68.3301     42.35        47          28
# 3        Vostok      RU  46.4856  135.8833     85.32        58         100
# 4     Busselton      AU -33.6500  115.3333     52.09        57         100
# 5  Ponta Do Sol      PT  32.6667  -17.1000     72.72        71           2
# 6        Albany      US  42.6001  -73.9662     72.25        79           0
# 7      Urubamba      PE -13.3047  -72.1158     52.70        87           8
# 8       Tubuala      PA   9.5167  -79.0333     78.33        86         100
# 9      Pochutla      MX  15.7432  -96.4661     82.81        92         100
#
#    Wind Speed Current Description
# 0        7.09          light rain
# 1        6.11           clear sky
# 2        3.60    scattered clouds
# 3        4.18     overcast clouds
# 4       26.02     overcast clouds
# 5        5.55           clear sky
# 6        1.01           clear sky
# 7        5.19           clear sky
# 8        6.08     overcast clouds
# 9        2.82     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
